# %%
import pandas as pd
from pathlib import Path

# Resolve path from notebook location so it works regardless of current working directory.
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
DATA_PATH = PROJECT_ROOT / "data" / "raw" / "synthetic_gambling_history_complete.csv"

df = pd.read_csv(DATA_PATH)

print(f"Loaded: {DATA_PATH}")
print(f"Shape: {df.shape}")
# Out:
# Loaded: /Users/tsing/Library/Mobile Documents/com~apple~CloudDocs/DataSci/Gambling-ML-/data/raw/synthetic_gambling_history_complete.csv
# Shape: (6000, 56)

# %%
pd.set_option("display.max_columns", None)
df.head()
# Out:
#    player_id signup_date   age primary_product_type  synthetic_income_monthly  \
# 0     100000  2018-03-07  60.0               casino               6925.921146
# 1     100001  2019-07-19  63.0           sportsbook               3550.777897
# 2     100002  2019-04-23  47.0           sportsbook               3292.481555
# 3     100003  2018-11-17  64.0           sportsbook               5919.411910
# 4     100004  2018-11-13  24.0               casino               6977.106485
#
#    debt_to_income_ratio  synthetic_credit_score  risk_profile  data_year  \
# 0              0.349098                   545.0             1       2020
# 1              1.254961                   805.0             0       2020
# 2              0.218748                   790.0             1       2020
# 3                   NaN                   715.0             0       2020
# 4              0.822921                   804.0             0       2020
#
#    account_tenure_days  credit_score_velocity_7d  liquid_savings_balance  \
# 0               1030.0                     -13.0            40994.362777
# 1                531.0                       6.0                     NaN
# 2                618.0                     -13.0            20192.918374
# 3                  NaN                      -8.0            18755.682654
# 4                779.0                     -28.0             1893.305832
#
#    liquid_savings_drawdown_rate  bank_decline_count_7d  total_bets_30d  \
# 0                      0.449016                    2.0           382.5
# 1                      0.123839                    NaN           243.0
# 2                      0.116550                    1.0             NaN
# 3                      0.266694                    0.0           344.0
# 4                      0.347809                    1.0           211.0
#
#    active_days_30d  avg_bets_per_active_day  avg_session_duration_minutes  \
# 0             17.0                22.500000                     95.092844
# 1              1.0               243.000000                    119.663911
# 2             15.0                76.500000                    149.687106
# 3             24.0                14.333333                     88.728737
# 4             25.0                 8.440000                     50.265873
#
#    total_handle_30d  net_loss_30d  avg_bet_size  max_bet_size  live_bet_ratio  \
# 0      15465.711773   6097.371306     40.327801    345.090536        0.090294
# 1      16469.267202  -1480.879802     67.496997    262.888449        0.958817
# 2      25828.767708  -2351.048248     22.489132    104.140545        0.891887
# 3      11272.459304   5010.764919     32.673795    224.783367        0.963019
# 4      10503.597490   4982.020610     49.545271    330.547943        0.808349
#
#    parlay_ratio  deposit_count_30d  deposit_amount_30d  avg_deposit_size  \
# 0      0.869107                9.0         1315.436068        131.543607
# 1      0.014635               13.0          714.283854         51.020275
# 2      0.264841                8.0          572.056522         63.561836
# 3      0.336922                9.0          793.077726               NaN
# 4      0.534864               11.0                 NaN        146.410531
#
#    deposit_growth_rate_4w  failed_deposit_count_30d  withdrawal_count_30d  \
# 0                0.970443                       4.0                   6.0
# 1                1.999153                       1.0                   6.0
# 2                1.499163                       3.0                   4.0
# 3                1.808907                       1.0                   2.0
# 4                1.187531                       0.0                   2.0
#
#    withdrawal_amount_30d  withdrawal_reversal_rate  rapid_redeposit_rate  \
# 0             913.341195                       NaN              1.351479
# 1            1803.572079                  0.075003              0.536338
# 2            8583.185223                  0.374456              0.694409
# 3            4019.951033                  0.245657              0.785160
# 4            5461.660889                  0.590752              0.551111
#
#    session_velocity_index  mean_inter_session_gap_hours  \
# 0                1.277256                     44.415306
# 1                2.055116                     99.378909
# 2                0.137548                     77.654329
# 3                1.559368                     55.843357
# 4                0.256383                     53.147801
#
#    inter_session_gap_trend  night_time_betting_ratio  weekend_betting_ratio  \
# 0                 1.734803                  0.206242               0.680353
# 1                 1.521319                  0.137949               0.118938
# 2                 0.426737                  0.765373               0.983960
# 3                -0.721482                  0.383739               0.343962
# 4                -0.127585                       NaN               0.632773
#
#    same_day_multiple_session_flag  post_loss_session_return_time_hours  \
# 0                             0.0                             4.980406
# 1                             0.0                            15.841894
# 2                             1.0                            13.063900
# 3                             0.0                             1.278752
# 4                             0.0                            14.344015
#
#    chase_magnitude_index  loss_streak_length_max  volatility_of_daily_losses  \
# 0               1.439477                     9.0                  354.313341
# 1               0.497769                    15.0                         NaN
# 2               3.387916                    11.0                   61.170919
# 3               2.694797                     1.0                   86.004006
# 4               1.056883                     2.0                   33.853994
#
#    bonus_offer_count_30d  bonus_redemption_rate  bonus_sensitivity_index  \
# 0                   14.0               1.020233                      NaN
# 1                   19.0               0.817242                 0.603085
# 2                   12.0               1.148631                 0.415533
# 3                    6.0               0.903107                 0.960713
# 4                   17.0                    NaN                 0.797903
#
#    push_notification_density  gambling_ad_ctr affiliate_referral_source  \
# 0                       39.0              NaN                       vip
# 1                       33.0         0.194006                       vip
# 2                       20.0         0.512708                   organic
# 3                       10.0         0.828974                       vip
# 4                       36.0         0.502300                       vip
#
#    vip_status  limit_setting_flag  deposit_limit_breach_attempts  \
# 0         0.0                 0.0                            5.0
# 1         0.0                 0.0                            1.0
# 2         0.0                 1.0                            1.0
# 3         0.0                 1.0                            2.0
# 4         0.0                 1.0                            NaN
#
#    time_out_requests_count  responsible_gambling_message_count  \
# 0                      1.0                                 4.0
# 1                      0.0                                 3.0
# 2                      0.0                                 1.0
# 3                      2.0                                18.0
# 4                      NaN                                18.0
#
#    regulatory_friction_score  friction_bypass_attempt_flag
# 0                   0.531839                           0.0
# 1                   0.943329                           0.0
# 2                   0.103561                           0.0
# 3                   0.989675                           0.0
# 4                   0.133529                           0.0

# %%
columns_df = pd.DataFrame({"column_name": df.columns})
columns_df.index = columns_df.index + 1
columns_df
# Out:
#                             column_name
# 1                             player_id
# 2                           signup_date
# 3                                   age
# 4                  primary_product_type
# 5              synthetic_income_monthly
# 6                  debt_to_income_ratio
# 7                synthetic_credit_score
# 8                          risk_profile
# 9                             data_year
# 10                  account_tenure_days
# 11             credit_score_velocity_7d
# 12               liquid_savings_balance
# 13         liquid_savings_drawdown_rate
# 14                bank_decline_count_7d
# 15                       total_bets_30d
# 16                      active_days_30d
# 17              avg_bets_per_active_day
# 18         avg_session_duration_minutes
# 19                     total_handle_30d
# 20                         net_loss_30d
# 21                         avg_bet_size
# 22                         max_bet_size
# 23                       live_bet_ratio
# 24                         parlay_ratio
# 25                    deposit_count_30d
# 26                   deposit_amount_30d
# 27                     avg_deposit_size
# 28               deposit_growth_rate_4w
# 29             failed_deposit_count_30d
# 30                 withdrawal_count_30d
# 31                withdrawal_amount_30d
# 32             withdrawal_reversal_rate
# 33                 rapid_redeposit_rate
# 34               session_velocity_index
# 35         mean_inter_session_gap_hours
# 36              inter_session_gap_trend
# 37             night_time_betting_ratio
# 38                weekend_betting_ratio
# 39       same_day_multiple_session_flag
# 40  post_loss_session_return_time_hours
# 41                chase_magnitude_index
# 42               loss_streak_length_max
# 43           volatility_of_daily_losses
# 44                bonus_offer_count_30d
# 45                bonus_redemption_rate
# 46              bonus_sensitivity_index
# 47            push_notification_density
# 48                      gambling_ad_ctr
# 49            affiliate_referral_source
# 50                           vip_status
# 51                   limit_setting_flag
# 52        deposit_limit_breach_attempts
# 53              time_out_requests_count
# 54   responsible_gambling_message_count
# 55            regulatory_friction_score
# 56         friction_bypass_attempt_flag

# %%
missing_summary = (
    df.isna()
      .sum()
      .sort_values(ascending=False)
      .rename("missing_count")
      .to_frame()
)
missing_summary["missing_pct"] = (missing_summary["missing_count"] / len(df) * 100).round(2)
missing_summary
# Out:
#                                      missing_count  missing_pct
# bonus_redemption_rate                          337         5.62
# failed_deposit_count_30d                       335         5.58
# deposit_growth_rate_4w                         332         5.53
# max_bet_size                                   329         5.48
# synthetic_income_monthly                       323         5.38
# avg_bet_size                                   319         5.32
# debt_to_income_ratio                           318         5.30
# avg_session_duration_minutes                   315         5.25
# rapid_redeposit_rate                           312         5.20
# total_bets_30d                                 312         5.20
# credit_score_velocity_7d                       310         5.17
# same_day_multiple_session_flag                 309         5.15
# liquid_savings_balance                         309         5.15
# withdrawal_count_30d                           309         5.15
# account_tenure_days                            308         5.13
# withdrawal_amount_30d                          308         5.13
# total_handle_30d                               307         5.12
# liquid_savings_drawdown_rate                   307         5.12
# night_time_betting_ratio                       307         5.12
# push_notification_density                      306         5.10
# affiliate_referral_source                      306         5.10
# post_loss_session_return_time_hours            306         5.10
# bonus_offer_count_30d                          305         5.08
# deposit_limit_breach_attempts                  304         5.07
# loss_streak_length_max                         301         5.02
# bank_decline_count_7d                          301         5.02
# parlay_ratio                                   300         5.00
# avg_deposit_size                               300         5.00
# bonus_sensitivity_index                        299         4.98
# friction_bypass_attempt_flag                   298         4.97
# deposit_count_30d                              297         4.95
# age                                            295         4.92
# avg_bets_per_active_day                        295         4.92
# time_out_requests_count                        292         4.87
# responsible_gambling_message_count             290         4.83
# synthetic_credit_score                         288         4.80
# deposit_amount_30d                             286         4.77
# active_days_30d                                285         4.75
# mean_inter_session_gap_hours                   285         4.75
# live_bet_ratio                                 285         4.75
# regulatory_friction_score                      285         4.75
# session_velocity_index                         282         4.70
# inter_session_gap_trend                        282         4.70
# gambling_ad_ctr                                282         4.70
# vip_status                                     281         4.68
# withdrawal_reversal_rate                       280         4.67
# chase_magnitude_index                          277         4.62
# weekend_betting_ratio                          277         4.62
# limit_setting_flag                             277         4.62
# volatility_of_daily_losses                     267         4.45
# net_loss_30d                                   265         4.42
# signup_date                                      0         0.00
# primary_product_type                             0         0.00
# risk_profile                                     0         0.00
# data_year                                        0         0.00
# player_id                                        0         0.00
